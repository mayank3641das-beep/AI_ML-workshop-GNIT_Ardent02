# %% [markdown]
# **grade** **calculator**

# %%
print("___smart grade calculator___")

name=input("enter student name:")

sub1=float(input("enter marks for subject 1:"))
sub2=float(input("enter marks for subject 2:"))
sub3=float(input("enter marks for subject 3:"))
sub4=float(input("enter marks for subject 4:"))
sub5=float(input("enter marks for subject 5:"))

total=sub1+sub2+sub3+sub4+sub5
avg=total/5

if avg>=90:
    grade='A+'
elif avg>=80:
    grade='A'
elif avg>=70:
    grade='B'
elif avg>=60:
    grade="C"
elif avg>=50:
    grade="D"
else:
    grade="F"

print("\n---result---")
print("student name:",name)
print("total marks:",total)
print("average marks:",avg)
print("grade:",grade)
# Out:
# ___smart grade calculator___
# enter student name:big yahu
# enter marks for subject 1:100
# enter marks for subject 2:100
# enter marks for subject 3:100
# enter marks for subject 4:67
# enter marks for subject 5:41
#
# ---result---
# student name: big yahu
# total marks: 408.0
# average marks: 81.6
# grade: A

# %% [markdown]
# simple calculator

# %%
print("___simple calculator___")

num1=float(input("enter first number:"))
num2=float(input("enter second number:"))

print("\n choose operation")
print("1.addition")
print("2.subtraction")
print("3.multiplication")
print("4.division")

choice=input("enter choice(1/2/3/4):")

if choice=="1":
    result=num1+num2
elif choice=="2":
    result=num1-num2
elif choice=="3":
    result=num1*num2
elif choice=="4":
    result=num1/num2
else:
    print("invalid choice")

print("result:",result)
# Out:
# ___simple calculator___
# enter first number:67
# enter second number:41
#
#  choose operation
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
# enter choice(1/2/3/4):1
# result: 108.0

# %% [markdown]
# **contact book mini project**

# %%
contacts={}
while True:
  print("\n===contact book===")
  print("1.add contact")
  print("2.view contact")
  print("3.edit contact")
  print("4.delete contact")
  print("5.exit")
  choice=input("enter your choice(1/2/3/4/5):")
  if choice=="1":
    name=input("enter contact name:")
    phone=input("enter contact phone:")
    contacts[name]=phone
    print("Contact added successfully.")
  elif choice=="2":
    if contacts:
      print("\nSaved contacts:")
      for name,phone in contacts.items():
        print(f"{name}:{phone}")
    else:
      print("No contacts saved yet.")


  elif choice=="3":
    name=input("enter contact name to edit:")
    if name in contacts:
      print("Current phone number:",contacts[name])
      new_phone = input("Enter new phone number: ")
      contacts[name] = new_phone
      print("Contact updated successfully.")
    else:
      print("Contact not found.")


  elif choice=="4":
    name=input("enter contact name to delete:")
    if name in contacts:
      del contacts[name]
      print("Contact deleted successfully.")
    else:
      print("Contact not found.")


  elif choice=="5":
    print("Exiting contact book.")
    break
  else:
    print("Invalid choice. Please enter a number between 1 and 5.")
# Out:
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):1
# enter contact name:cia
# enter contact phone:194-5988907
# Contact added successfully.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):2
#
# Saved contacts:
# cia:194-5988907
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):1
# enter contact name:mossad
# enter contact phone:9786370912
# Contact added successfully.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):3
# enter contact name to edit:modi
# Contact not found.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):2
#
# Saved contacts:
# cia:194-5988907
# mossad:9786370912
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):1
# enter contact name:john kiriakou(47 cruise missiles)
# enter contact phone:0129898789083
# Contact added successfully.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):3
# enter contact name to edit:modi
# Contact not found.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):2
#
# Saved contacts:
# cia:194-5988907
# mossad:9786370912
# john kiriakou(47 cruise missiles):0129898789083
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):1
# enter contact name:osama
# enter contact phone:911911911
# Contact added successfully.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):1
# enter contact name:jewish nigga
# enter contact phone:6676767676767
# Contact added successfully.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):2
#
# Saved contacts:
# cia:194-5988907
# mossad:9786370912
# john kiriakou(47 cruise missiles):0129898789083
# osama:911911911
# jewish nigga:6676767676767
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# enter your choice(1/2/3/4/5):omen
# Invalid choice. Please enter a number between 1 and 5.
#
# ===contact book===
# 1.add contact
# 2.view contact
# 3.edit contact
# 4.delete contact
# 5.exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_578/1520754388.py in <cell line: 0>()
#       7   print("4.delete contact")
#       8   print("5.exit")
# ----> 9   choice=input("enter your choice(1/2/3/4/5):")
#      10   if choice=="1":
#      11     name=input("enter contact name:")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
